# %%
# !pip install sentence-transformers

# %%
# !python resume_matcher.py
# Out:
# ── Resume ────────────────────────────────────────────────────────
# Skills: Python, Machine Learning, NLP, SQL, Deep Learning
# Technologies: PyTorch, HuggingFace Transformers, FastAPI, PostgreSQL, Docker, FAISS
# Certifications: AWS Cloud Practitioner
# Experience: 2 years building NLP pipelines: fine-tuned BERT for NER, built a RAG-based QA system, deployed models with FastAPI on AWS.
# Education: B.Tech Computer Science
#
# ── Matching roles (bi-encoder + reranker) ─────────────────────────
# Loading bi-encoder: BAAI/bge-small-en-v1.5 ...
# modules.json: 100% 349/349 [00:00<00:00, 983kB/s]
# config_sentence_transformers.json: 100% 124/124 [00:00<00:00, 417kB/s]
# ...
# README.md: 94.8kB [00:00, 38.3MB/s]
# sentence_bert_config.json: 100% 52.0/52.0 [00:00<00:00, 169kB/s]
# config.json: 100% 743/743 [00:00<00:00, 2.15MB/s]
# model.safetensors: 100% 133M/133M [00:01<00:00, 68.3MB/s]
# Loading weights: 100% 199/199 [00:00<00:00, 850.20it/s, Materializing param=pooler.dense.weight]
# ...

# %%
# !python resume_matcher.py
# Out:
# ── Resume ────────────────────────────────────────────────────────
# Skills: Python, Machine Learning, NLP, SQL, Deep Learning
# Technologies: PyTorch, HuggingFace Transformers, FastAPI, PostgreSQL, Docker, FAISS
# Certifications: AWS Cloud Practitioner
# Experience: 2 years building NLP pipelines: fine-tuned BERT for NER, built a RAG-based QA system, deployed models with FastAPI on AWS.
# Education: B.Tech Computer Science
#
# ── Matching roles (bi-encoder + reranker) ─────────────────────────
# Loading bi-encoder: BAAI/bge-small-en-v1.5 ...
# ...
# Loading weights: 100% 199/199 [00:00<00:00, 1113.56it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-small-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ...
